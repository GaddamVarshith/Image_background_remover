# %%
from PIL import Image
import rembg

# %%
img = Image.open(r"C:\Users\Varshith\Downloads\virat.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=612x383>

# %%
removed_background = rembg.remove(img)
removed_bg
# Out:
# ...
# 100%|########################################| 176M/176M [00:00<00:00, 176GB/s]
# <PIL.Image.Image image mode=RGBA size=612x383>
